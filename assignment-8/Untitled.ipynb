# %%
import pdb
list1 = [1,2,3,4,5]
list2 = [3,4,5,6,7,8,8,9,9,9,9,9,9,9,9,9,9,9]

comp_list = [list1, list2]


for i in range(len(comp_list)):

    if len(comp_list[i])>10:
        comp_list[i] = comp_list[i][0:10]
        
    else:
        list_len = 10 - len(comp_list[i])
        zero_array = [0 for item in range(list_len)]
        comp_list[i].extend(zero_array)

print(comp_list)
# Out:
# [[1, 2, 3, 4, 5, 0, 0, 0, 0, 0], [3, 4, 5, 6, 7, 8, 8, 9, 9, 9]]
