# %%
import pdb
list1 = [1,2,3,4,5]
list2 = [3,4,5,6,7,8,8,9,9,9,9,9,9,9,9,9,9,9]

comp_list = [list1, list2]

for list in comp_list:

    if len(list)>10:
        list = list[0:10]
        
    else:
        list_len = 10 - len(list)
        zero_array = [0 for item in range(list_len)]
        list.extend(zero_array)

print(comp_list)
# Out:
#     [... skipping 21 hidden frame(s)]
# > /var/folders/38/ff849qvn7030y_hf5jk71hth0000gn/T/ipykernel_69137/200132979.py(9)<module>()
#       7 for list in comp_list:
#       8
# ----> 9     pdb.set_trace()
#      10     if len(list)>10:
#      11         list = list[0:10]
